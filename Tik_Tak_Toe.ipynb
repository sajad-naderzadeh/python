# %%
# Tic Tack Toe
import random


choose_mode = input("choose either want to play with computer or play multi player:   [computer, 2player]   ")
if (choose_mode == "2player"):
  player_1 = input("Enter Player 1 name:")
  print("\n")
  player_2 = input("Enter Player 2 name:")
else:
  computer = "computer"


def main():
# The main function
    if(choose_mode == '2player'):
      introduction = intro()
      board = create_grid()
      pretty = printPretty(board)
      symbol_1, symbol_2 = sym()
      full = isFull(board, symbol_1, symbol_2) # The function that starts the game is also in here.

    else:
      introduction = intro()
      board = create_grid()
      pretty = printPretty(board)
      symboll_1, symboll_2 = sym_with_computer()
      full = isFullForComputer(board, symboll_1, symboll_2) # The function that starts the game is also in here.





def intro():
# This function introduces the rules of the game Tic Tac Toe
    print("Hello! Welcome to Tic Tac Toe game!")
    print("\n")
    if (choose_mode == "2player"):
      print(f"Rules: {player_1} and {player_2}, represented by X and O, take turns "
          "marking the spaces in a 3*3 grid. The player who succeeds in placing "
          "three of their marks in a horizontal, vertical, or diagonal row wins.")
    else:
      print(f"Rules: {player_1}, represented by X and O, take turns "
          "marking the spaces in a 3*3 grid. The player who succeeds in placing "
          "three of their marks in a horizontal, vertical, or diagonal row wins.")
    print("\n")
    input("Press enter to continue.")
    print("\n")



def create_grid():
# This function creates a blank playboard
    print("Here is the playboard: ")
    board = [[" ", " ", " "],
             [" ", " ", " "],
             [" ", " ", " "]]
    return board


def sym_with_computer():
# This function decides the players' symbols
    symboll_1 = input(f"{player_1}, do you want to be X or O? ")
    if symboll_1 == "X":
        symboll_2 = "O"
        print(f"{player_1}, you are X. ")
        print("\n")
        print(f"{computer}, you are O. ")
        #return (symbol_1, symbol_2)
    else:
          symboll_2 = "X"
          symboll_1 = "O"
          print(f"{computer}, you are X. ")
          print(f"{player_1}, you are O. ")
    input("Press enter to continue.")
    print("\n")
    return (symboll_1, symboll_2)

def sym():
# This function decides the players' symbols
    symbol_1 = input(f"{player_1}, do you want to be X or O? ")
    if symbol_1 == "X":
        symbol_2 = "O"
        print(f"{player_1}, you are X. ")
        print("\n")
        print(f"{player_2}, you are O. ")
        #return (symbol_1, symbol_2)
    else:
          symbol_2 = "X"
          symbole_1 = "O"
          print(f"{player_2}, you are X. ")
          print(f"{player_1}, you are O. ")
    input("Press enter to continue.")
    print("\n")
    return (symbol_1, symbol_2)



def startGammingWithComputer(board, symboll_1, symboll_2, count):
# This function starts the game.

    # Decides the turn
    if count % 2 == 0:
        player = player_1
        print(f"{player} it is your turn. ")
        row = int(input("Pick a row:"
                    "[upper row: enter 0,"
                    "middle row: enter 1,"
                    "bottom row: enter 2]:"))
        column = int(input("Pick a column:"
                       "[left column: enter 0,"
                        "middle column: enter 1,"
                        "right column enter 2]"))


    # Check if players' selection is out of range
    if (row > 2 or row < 0) or (column > 2 or column < 0):
        outOfBoard(row, column)
        row = int(input("Pick a row:"
                    "[upper row: enter 0,"
                    "middle row: enter 1,"
                    "bottom row: enter 2]:"))
        column = int(input("Pick a column:"
                       "[left column: enter 0,"
                        "middle column: enter 1,"
                        "right column enter 2]"))

        # Check if the square is already filled
    if (board[row][column] == player_1)or (board[row][column] == player_2):
        filled = illegalComputer(board, player_1, computer, row, column)
        row = int(input("Pick a row:"
                    "[upper row: enter 0,"
                    "middle row: enter 1,"
                    "bottom row: enter 2]:"))
        column = int(input("Pick a column:"
                       "[left column: enter 0,"
                        "middle column: enter 1,"
                        "right column enter 2]"))

    elif count % 2 == 1:
        player = computer
        print(f"{computer} turn. ")
        row = random.randint(0, 2)
        column = random.randint(0, 2)

        if (row > 2 or row < 0) or (column > 2 or column < 0):
          outOfBoard(row, column)
          row = random.randint(0, 2)
          column = random.randint(0, 2)

        if (board[row][column] == player_1)or (board[row][column] == player_2):
          filled = illegal(board, player_1, computer, row, column)
          row = random.randint(0, 2)
          column = random.randint(0, 2)

    # Locates player's symbol on the board
    if player == player_1:
        board[row][column] = symboll_1

    else:
        board[row][column] = symboll_2

    return (board)



def startGamming(board, symbol_1, symbol_2, count):
# This function starts the game.

    # Decides the turn
    if count % 2 == 0:
        player = player_1
    elif count % 2 == 1:
        player = player_2
    print(f"{player} it is your turn. ")
    row = int(input("Pick a row:"
                    "[upper row: enter 0,"
                    "middle row: enter 1,"
                    "bottom row: enter 2]:"))
    column = int(input("Pick a column:"
                       "[left column: enter 0,"
                        "middle column: enter 1,"
                        "right column enter 2]"))


    # Check if players' selection is out of range
    if (row > 2 or row < 0) or (column > 2 or column < 0):
        outOfBoard(row, column)
        row = int(input("Pick a row:"
                    "[upper row: enter 0,"
                    "middle row: enter 1,"
                    "bottom row: enter 2]:"))
        column = int(input("Pick a column:"
                       "[left column: enter 0,"
                        "middle column: enter 1,"
                        "right column enter 2]"))

        # Check if the square is already filled
    if (board[row][column] == player_1)or (board[row][column] == player_2):
        filled = illegal(board, player_1, player_2, row, column)
        row = int(input("Pick a row:"
                    "[upper row: enter 0,"
                    "middle row: enter 1,"
                    "bottom row: enter 2]:"))
        column = int(input("Pick a column:"
                       "[left column: enter 0,"
                        "middle column: enter 1,"
                        "right column enter 2]"))

    # Locates player's symbol on the board
    if player == player_1:
        board[row][column] = symbol_1

    else:
        board[row][column] = symbol_2

    return (board)



def isFull(board, player_1, player_2):
    count = 1
    winner = True
# This function check if the board is full
    while count < 10 and winner == True:
        gaming = startGamming(board, player_1, player_2, count)
        pretty = printPretty(board)

        if count == 9:
            print("The board is full. Game over.")
            if winner == True:
                print("There is a tie. ")

        # Check if here is a winner
        winner = isWinner(board, player_1, player_2, count)
        count += 1
    if winner == False:
        print("Game over.")

    # This is function gives a report
    report(count, winner, player_1, player_2)


def isFullForComputer(board, player_1, computer):
    count = 1
    winner = True
# This function check if the board is full
    while count < 10 and winner == True:
        gaming = startGammingWithComputer(board, player_1, computer, count)
        pretty = printPretty(board)

        if count == 9:
            print("The board is full. Game over.")
            if winner == True:
                print("There is a tie. ")

        # Check if here is a winner
        winner = isWinnerVsComputer(board, player_1, computer, count)
        count += 1
    if winner == False:
        print("Game over.")

    # This is function gives a report
    report(count, winner, player_1, computer)



def outOfBoard(row, column):
# This function tells the players that their selection is out of range
    print("Out of boarder. Pick another one. ")



def printPretty(board):
# This function prints the board nice!
    rows = len(board)
    cols = len(board)
    print("---+---+---")
    for r in range(rows):
        print(board[r][0], " |", board[r][1], "|", board[r][2])
        print("---+---+---")
    return board



def isWinner(board, symbol_1, player_2, count):
# This function checks if any winner is winning
    winner = True
    # Check the rows
    for row in range (0, 3):
        if (board[row][0] == board[row][1] == board[row][2] == player_1):
            winner = False
            print("Player " + player_1 + ", you won!")

        elif (board[row][0] == board[row][1] == board[row][2] == player_2):
            winner = False
            print("Player " + player_2 + ", you won!")


    # Check the columns
    for col in range (0, 3):
        if (board[0][col] == board[1][col] == board[2][col] == player_1):
            winner = False
            print("Player " + player_1 + ", you won!")
        elif (board[0][col] == board[1][col] == board[2][col] == player_2):
            winner = False
            print("Player " + player_2 + ", you won!")

    # Check the diagnoals
    if board[0][0] == board[1][1] == board[2][2] == player_1:
        winner = False
        print("Player " + player_1 + ", you won!")

    elif board[0][0] == board[1][1] == board[2][2] == player_2:
        winner = False
        print("Player " + player_2 + ", you won!")

    elif board[0][2] == board[1][1] == board[2][0] == player_1:
        winner = False
        print("Player " + player_1 + ", you won!")

    elif board[0][2] == board[1][1] == board[2][0] == player_2:
        winner = False
        print("Player " + player_2 + ", you won!")

    return winner




def isWinnerVsComputer(board, symboll_1, computer, count):
# This function checks if any winner is winning
    winner = True
    # Check the rows
    for row in range (0, 3):
        if (board[row][0] == board[row][1] == board[row][2] == player_1):
            winner = False
            print("Player " + player_1 + ", you won!")

        elif (board[row][0] == board[row][1] == board[row][2] == computer):
            winner = False
            print("Player " + computer + ", you won!")


    # Check the columns
    for col in range (0, 3):
        if (board[0][col] == board[1][col] == board[2][col] == player_1):
            winner = False
            print("Player " + player_1 + ", you won!")
        elif (board[0][col] == board[1][col] == board[2][col] == computer):
            winner = False
            print("Player " + computer + ", you won!")

    # Check the diagnoals
    if board[0][0] == board[1][1] == board[2][2] == player_1:
        winner = False
        print("Player " + player_1 + ", you won!")

    elif board[0][0] == board[1][1] == board[2][2] == computer:
        winner = False
        print("Player " + computer + ", you won!")

    elif board[0][2] == board[1][1] == board[2][0] == player_1:
        winner = False
        print("Player " + player_1 + ", you won!")

    elif board[0][2] == board[1][1] == board[2][0] == computer:
        winner = False
        print("Player " + computer + ", you won!")

    return winner



def illegal(board, symbol_1, player_2, row, column):
    print("The square you picked is already filled. Pick another one.")


def illegalComputer(board, symboll_1, computer, row, column):
    print("The square you picked is already filled. Pick another one.")

def report(count, winner, player_1, player_2):
    print("\n")
    input("Press enter to see the game summary. ")
    if (winner == False) and (count % 2 == 1 ):
        print("Winner : Player " + player_1 + ".")
    elif (winner == False) and (count % 2 == 0 ):
        print("Winner : Player " + player_2 + ".")
    else:
        print("There is a tie. ")



def reportComputer(count, winner, player_1, computer):
    print("\n")
    input("Press enter to see the game summary. ")
    if (winner == False) and (count % 2 == 1 ):
        print("Winner : Player " + player_1 + ".")
    elif (winner == False) and (count % 2 == 0 ):
        print("Winner : Player " + computer + ".")
    else:
        print("There is a tie. ")

# Call Main
main()
